# %%
import pandas as pd

# %%
test = pd.read_csv('../data/test.csv')
test
# Out:
#            ID 매물확인방식          보증금      월세   전용면적   해당층    총층   방향   방수  욕실수  \
# 0    TEST_000   서류확인  223000000.0  530000    NaN   5.0   5.0   남향  1.0  1.0
# 1    TEST_001   서류확인  150500000.0  590000  30.26   7.0  11.0   서향  1.0  1.0
# 2    TEST_002   현장확인   47000000.0  200000  41.50   2.0   3.0  남서향  2.0  1.0
# 3    TEST_003   서류확인  133000000.0  250000  31.35   5.0   6.0   남향  2.0  1.0
# 4    TEST_004   현장확인  108000000.0  380000  23.14   2.0   3.0   남향  1.0  1.0
# ..        ...    ...          ...     ...    ...   ...   ...  ...  ...  ...
# 608  TEST_608   현장확인  152500000.0  340000  30.83   4.0   6.0  남동향  1.0  1.0
# 609  TEST_609   전화확인  226500000.0  750000  29.88   NaN  10.0  남서향  2.0  1.0
# 610  TEST_610   현장확인  169500000.0  500000  30.73   5.0   6.0   남향  1.0  1.0
# 611  TEST_611   현장확인  180000000.0  340000  17.50   3.0   6.0  남동향  1.0  1.0
# 612  TEST_612   현장확인  143000000.0  360000  21.09  10.0  15.0   동향  2.0  2.0
#
#     주차가능여부  총주차대수  관리비       중개사무소 제공플랫폼         게재일
# 0      불가능    NaN    7  Z86Th6S3K5  D플랫폼  2024-10-21
# 1      불가능   16.0   11  G52Iz8V2B9  D플랫폼  2023-09-02
# 2      불가능    NaN    0  N45gM0M7R0  B플랫폼  2024-04-03
# 3       가능    NaN    5  C41wx1K6U9  B플랫폼  2024-09-19
# 4      불가능    NaN    0  Z68ZJ6F6L4  A플랫폼  2024-11-10
# ..     ...    ...  ...         ...   ...         ...
# 608     가능    1.0    2  j90UQ8N6M3  A플랫폼  2024-09-24
# 609     가능   34.0    7  r82ax9M3U3  B플랫폼  2024-09-04
# 610    불가능   33.0    6  G52Iz8V2B9  F플랫폼  2024-04-20
# 611     가능    2.0    8  J52gJ2E4T6  C플랫폼  2024-11-17
# 612     가능   47.0    6  G52Iz8V2B9  B플랫폼  2024-05-04
#
# [613 rows x 16 columns]

# %%
test["보증금"] = test["보증금"] / 10000
test["월세"] = test["월세"] / 10000

# %%
test.to_csv('./saved/test.csv', index = False)
